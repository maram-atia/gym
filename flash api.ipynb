# %%
from flask import Flask, jsonify, request
import pandas as pd
processed_exercise_data = process_exercise_data(exercises_df)

app = Flask(__name__)

# Ensure you load your processed_exercise_data correctly here
# processed_exercise_data = pd.read_csv('path_to_your_data.csv')

def get_exercises_by_muscle(processed_data, muscle):
    muscle = muscle.lower()  # Convert the muscle parameter to lowercase
    # Filter exercises that involve the specified muscle
    # Checking if the muscle is in any of the list's elements, accounting for case
    result = processed_data[processed_data['muscles_involved'].apply(lambda x: any(muscle in m.lower() for m in x))]
    return result

@app.route('/exercises', methods=['GET'])
def exercises_by_muscle():
    muscle = request.args.get('muscle', None)
    if not muscle:
        return jsonify({'error': 'Muscle parameter is required'}), 400
    try:
        result = get_exercises_by_muscle(processed_exercise_data, muscle)
        if result.empty:
            return jsonify({'message': 'No exercises found for the given muscle'}), 404
    except Exception as e:
        return jsonify({'error': str(e)}), 500
    return jsonify(result.to_dict(orient='records'))

if __name__ == '__main__':
    from werkzeug.serving import run_simple
    run_simple('localhost', 9000, app, use_reloader=False)

# %%
# Out:
# Status Code: 200
# Response Body: [{"Benefits":NaN,"Category":["Quadriceps exercises","Gluteal exercises","Exercices hamstrings"],"Equipement":["kettlebell"],"Level":"intermediate","Mistake to Avoid ":NaN,"Steps":{"How to make the Goblet squat with Kettlebell?":["1: Place a kettlebell at the top of your chest.Hold the handles of the kettle with both hands.","2: Your feet will be spaced the width of the shoulders (or slightly superior), and oriented slightly outwards.","3: Take a great inspiration and descend by pushing the hips back and simultaneously folding the knees.","4: Continue the descent until the fold of your hips is lower than your knees.","5: Go up by pushing your feet into the ground, stretching your knees and hips until you are again in a high position.Exhale.","6: Repeat this movement until you have made the desired number of rehearsals."]},"Tips ":{"Training advice":["If you have trouble making squats with a bar, this is the best version to help you work the squat vertically.","A dowters Kettlebell squat with Kettlebell will cause better leg development, because adductors will then be involved in the movement.","Always keep your elbows noted to maintain a better balance.","A certain translation of the knees forward compared to the toes is acceptable provided that the knees do not deviate excessively inward or outside.People whose femur is longer will have to let their knees come further forward if they want to remain straight."]},"Type de Exercice":["other"],"Variants":NaN,"Video":NaN,"_id":1,"image_src_note":{"caption":"The muscles requested in the Goblet squat with Kettlebell.","src":"https://www.docteur-fitness.com/wp-content/uploads/2021/12/squat-goblet-kettlebell.gif"},"muscles_involved":["quadriceps"],"name":"Squat Goblet with Kettlebell"},{"Benefits":NaN,"Category":["Quadriceps exercises"],"Equipement":["bench"],"Level":"intermediate","Mistake to Avoid ":NaN,"Steps":{"How to do the squat on a bench?":["1: Install an ordinary flat bench behind you.","2: Placez une barre de weight training sur vos trap\u00e8zes sup\u00e9rieurs, l\u00e9g\u00e8rement au-dessus des \u00e9paules, et empoignez bien la barre.","3: Adopt a spacing of the feet of the shoulder width.Contract the abdominal muscles, open your chest and keep the lower eight back.","4: Inspire then initiate the squat by folding the hips and knees.When your buttocks touch the bench, push on your heels to get up.Exhale at the end of the movement.","5: Keep your abdominal belt tight and your right back throughout the exercise.","6: Repeat the exercise until you have done the desired number of rehearsals."]},"Tips ":{"Training advice":["Do not switch too much behind to the point of disengaging the hips.","In high position, keep a slight knee bending to keep the tension on the leg muscles.","As with all flexion movements on the legs, do not rotate your knees inward or outside: they will have to stay in the heel-tie axis throughout the exercise."]},"Type de Exercice":["other"],"Variants":NaN,"Video":NaN,"_id":4,"image_src_note":{"caption":"The muscles asked for the squat on a bench.","src":"https://www.docteur-fitness.com/wp-content/uploads/2021/12/squat-sur-banc.gif"},"muscles_involved":["back","glutes","quadriceps","hamstrings","abdominals"],"name":"Squat on bench"},{"Benefits":NaN,"Category":["Quadriceps exercises","Gluteal exercises"],"Equipement":["no_need"],"Level":"beginner","Mistake to Avoid ":NaN,"Steps":{"How to make the thigh press?":["1: Sit on the thigh press machine, your back well-plated against the folder.","2: Place your feet on the plate or resistance support.Your feet should be removed from the width of the hips or slightly more spaced.Your whole foot must be in contact with the resistance surface, ensuring above all to keep the heel well anchored.Your legs should form an angle of 90 degrees.","3: Enter the handles to stabilize your upper body.","4: Push strongly with your legs to move the weight battery.Your legs should be stretched and your knees slightly f ...
